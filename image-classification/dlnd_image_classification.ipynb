# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 3:
# Image - Min Value: 40 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = (x-x.min())/(x.max()-x.min())
    return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    n_classes = 10
    return np.eye(n_classes)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, *image_shape], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, [None, n_classes], name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    n_shape = x_tensor.get_shape().as_list()[-1]
    
    # weights
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], n_shape, conv_num_outputs], stddev=0.1))
    # bias
    bias = tf.Variable(tf.zeros([conv_num_outputs]))
    
    # Convolution Layer
    strides = [1, conv_strides[0], conv_strides[1], 1]
    
    conv_layer = tf.nn.conv2d(x_tensor, weights, strides, padding='SAME')    
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    # max_pool
    
    conv_layer = tf.nn.max_pool(conv_layer, [1, pool_ksize[0], pool_ksize[1], 1], [1, pool_strides[0], pool_strides[1], 1], 'SAME')
    return conv_layer
#     return None 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, shape[1]*shape[2]*shape[3]])
#     return None

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    n_shape = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([n_shape, num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    fc_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    fc_layer = tf.nn.relu(fc_layer)
    return fc_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([shape[1], num_outputs], stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    out_put_layer = tf.add(tf.matmul(x_tensor, weights), bias)
    return out_put_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x,    32,  (8,8), (1,1), (2,2), (2,2))
    conv = conv2d_maxpool(conv, 64,  (4,4), (1,1), (2,2), (2,2))
    conv = conv2d_maxpool(conv, 256, (2,2), (1,1), (2,2), (2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x_flat = flatten(conv)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc = fully_conn(x_flat, num_outputs = 512)
    fc = fully_conn(fc, num_outputs = 256)
    fc = tf.nn.dropout(fc, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    output_layer = output(fc, num_outputs = 10)
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(
        optimizer, 
        feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: keep_probability
    })

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    
    train_acc = session.run(accuracy, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })
    
    print('Loss: {:>10.4f} , Training Acc: {:.4f}, Validation Acc: {:.4f}'
          .format( loss, train_acc, valid_acc))

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0108 , Training Acc: 0.3750, Validation Acc: 0.3500
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7903 , Training Acc: 0.4250, Validation Acc: 0.4072
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.6067 , Training Acc: 0.4250, Validation Acc: 0.4442
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.3786 , Training Acc: 0.5250, Validation Acc: 0.4938
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.2364 , Training Acc: 0.6000, Validation Acc: 0.4794
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.0392 , Training Acc: 0.6750, Validation Acc: 0.4950
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.8703 , Training Acc: 0.7250, Validation Acc: 0.5158
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.7001 , Training Acc: 0.8000, Validation Acc: 0.5280
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.6034 , Training Acc: 0.8500, Validation Acc: 0.5252
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.5522 , Training Acc: 0.8750, Validation Acc: 0.5042
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.4562 , Training Acc: 0.9000, Validation Acc: 0.5330
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.3276 , Training Acc: 0.9500, Validation Acc: 0.5364
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.3813 , Training Acc: 0.9250, Validation Acc: 0.5294
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.2587 , Training Acc: 0.9750, Validation Acc: 0.5410
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.1914 , Training Acc: 0.9500, Validation Acc: 0.5396
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.1314 , Training Acc: 1.0000, Validation Acc: 0.5392
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0613 , Training Acc: 1.0000, Validation Acc: 0.5538
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0839 , Training Acc: 1.0000, Validation Acc: 0.5400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0530 , Training Acc: 1.0000, Validation Acc: 0.5286
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0328 , Training Acc: 1.0000, Validation Acc: 0.5372
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0304 , Training Acc: 1.0000, Validation Acc: 0.5346
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0351 , Training Acc: 1.0000, Validation Acc: 0.5320
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0176 , Training Acc: 1.0000, Validation Acc: 0.5306
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0163 , Training Acc: 1.0000, Validation Acc: 0.5340
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0243 , Training Acc: 1.0000, Validation Acc: 0.5046
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0058 , Training Acc: 1.0000, Validation Acc: 0.5296
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0055 , Training Acc: 1.0000, Validation Acc: 0.5448
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0081 , Training Acc: 1.0000, Validation Acc: 0.5412
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0170 , Training Acc: 1.0000, Validation Acc: 0.5216
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0019 , Training Acc: 1.0000, Validation Acc: 0.5458
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0014 , Training Acc: 1.0000, Validation Acc: 0.5376
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0040 , Training Acc: 1.0000, Validation Acc: 0.5432
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.5364
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0018 , Training Acc: 1.0000, Validation Acc: 0.5366
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0019 , Training Acc: 1.0000, Validation Acc: 0.5416
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0059 , Training Acc: 1.0000, Validation Acc: 0.5318
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.5372
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0043 , Training Acc: 1.0000, Validation Acc: 0.5278
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0014 , Training Acc: 1.0000, Validation Acc: 0.5370
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0034 , Training Acc: 1.0000, Validation Acc: 0.5444
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.5280
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0025 , Training Acc: 1.0000, Validation Acc: 0.5388
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0027 , Training Acc: 1.0000, Validation Acc: 0.5390
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0181 , Training Acc: 1.0000, Validation Acc: 0.5094
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.5228
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.5454
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.5390
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0043 , Training Acc: 1.0000, Validation Acc: 0.5412
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.5512
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0040 , Training Acc: 1.0000, Validation Acc: 0.5328

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.9616 , Training Acc: 0.3000, Validation Acc: 0.3640
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.6938 , Training Acc: 0.4500, Validation Acc: 0.4090
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.4955 , Training Acc: 0.4500, Validation Acc: 0.4248
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.4919 , Training Acc: 0.4500, Validation Acc: 0.4454
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.5519 , Training Acc: 0.4250, Validation Acc: 0.4906
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.6214 , Training Acc: 0.4500, Validation Acc: 0.4994
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.3512 , Training Acc: 0.5500, Validation Acc: 0.5106
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.1782 , Training Acc: 0.5750, Validation Acc: 0.5134
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.2169 , Training Acc: 0.5250, Validation Acc: 0.5308
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.2916 , Training Acc: 0.5750, Validation Acc: 0.5332
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.5148 , Training Acc: 0.5000, Validation Acc: 0.5240
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.0614 , Training Acc: 0.6000, Validation Acc: 0.5592
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.0222 , Training Acc: 0.7250, Validation Acc: 0.5480
# Epoch  3, CIFAR-10 Batch 4:  Loss:     0.9986 , Training Acc: 0.6250, Validation Acc: 0.5742
# Epoch  3, CIFAR-10 Batch 5:  Loss:     0.9343 , Training Acc: 0.6750, Validation Acc: 0.5888
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.1342 , Training Acc: 0.6250, Validation Acc: 0.5752
# Epoch  4, CIFAR-10 Batch 2:  Loss:     0.8257 , Training Acc: 0.7500, Validation Acc: 0.5828
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.7446 , Training Acc: 0.8000, Validation Acc: 0.5954
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.8605 , Training Acc: 0.6250, Validation Acc: 0.5944
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.7095 , Training Acc: 0.8250, Validation Acc: 0.6054
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.9448 , Training Acc: 0.6750, Validation Acc: 0.6030
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.6476 , Training Acc: 0.7750, Validation Acc: 0.6248
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.5413 , Training Acc: 0.8000, Validation Acc: 0.5950
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.6321 , Training Acc: 0.7750, Validation Acc: 0.6288
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.4622 , Training Acc: 0.9000, Validation Acc: 0.6258
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.7675 , Training Acc: 0.8000, Validation Acc: 0.6176
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.5853 , Training Acc: 0.7250, Validation Acc: 0.6104
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.4477 , Training Acc: 0.8500, Validation Acc: 0.6190
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.4491 , Training Acc: 0.9000, Validation Acc: 0.6370
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.3848 , Training Acc: 0.9250, Validation Acc: 0.6142
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.5969 , Training Acc: 0.8250, Validation Acc: 0.6204
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.3863 , Training Acc: 0.8750, Validation Acc: 0.6318
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.3144 , Training Acc: 0.9500, Validation Acc: 0.6216
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.4249 , Training Acc: 0.8250, Validation Acc: 0.6334
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.3157 , Training Acc: 0.9500, Validation Acc: 0.6158
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.3851 , Training Acc: 0.9250, Validation Acc: 0.6240
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.3379 , Training Acc: 0.8750, Validation Acc: 0.6304
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.2130 , Training Acc: 0.9750, Validation Acc: 0.6316
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.2712 , Training Acc: 0.9750, Validation Acc: 0.6380
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.2146 , Training Acc: 0.9500, Validation Acc: 0.6058
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.3528 , Training Acc: 0.8750, Validation Acc: 0.6264
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.2096 , Training Acc: 0.9750, Validation Acc: 0.6406
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.2419 , Training Acc: 0.9250, Validation Acc: 0.6360
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.1661 , Training Acc: 0.9750, Validation Acc: 0.6476
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.1303 , Training Acc: 1.0000, Validation Acc: 0.6086
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.2260 , Training Acc: 0.9750, Validation Acc: 0.6354
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.2936 , Training Acc: 0.9000, Validation Acc: 0.6298
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.1571 , Training Acc: 0.9500, Validation Acc: 0.6334
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.1142 , Training Acc: 0.9750, Validation Acc: 0.6364
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.0881 , Training Acc: 1.0000, Validation Acc: 0.6450
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.1815 , Training Acc: 0.9500, Validation Acc: 0.6532
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.1764 , Training Acc: 0.9250, Validation Acc: 0.6510
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.1440 , Training Acc: 0.9500, Validation Acc: 0.6426
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.1451 , Training Acc: 0.9750, Validation Acc: 0.6262
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.1031 , Training Acc: 0.9750, Validation Acc: 0.6334
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.1769 , Training Acc: 0.9750, Validation Acc: 0.6368
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.1176 , Training Acc: 0.9750, Validation Acc: 0.6364
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.1115 , Training Acc: 1.0000, Validation Acc: 0.6422
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.0472 , Training Acc: 1.0000, Validation Acc: 0.6432
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.0786 , Training Acc: 0.9750, Validation Acc: 0.6452
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.0877 , Training Acc: 1.0000, Validation Acc: 0.6440
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.1157 , Training Acc: 1.0000, Validation Acc: 0.6290
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.0565 , Training Acc: 0.9750, Validation Acc: 0.6260
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.0280 , Training Acc: 1.0000, Validation Acc: 0.6368
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.0244 , Training Acc: 1.0000, Validation Acc: 0.6378
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.0749 , Training Acc: 1.0000, Validation Acc: 0.6352
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.0617 , Training Acc: 1.0000, Validation Acc: 0.6164
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.0765 , Training Acc: 1.0000, Validation Acc: 0.6216
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.0261 , Training Acc: 1.0000, Validation Acc: 0.6352
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.0484 , Training Acc: 1.0000, Validation Acc: 0.6262
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.0494 , Training Acc: 1.0000, Validation Acc: 0.6462
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.0544 , Training Acc: 0.9750, Validation Acc: 0.6134
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0392 , Training Acc: 1.0000, Validation Acc: 0.6340
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.0223 , Training Acc: 1.0000, Validation Acc: 0.6438
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.0146 , Training Acc: 1.0000, Validation Acc: 0.6500
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.0306 , Training Acc: 1.0000, Validation Acc: 0.6378
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.0625 , Training Acc: 1.0000, Validation Acc: 0.6260
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.0199 , Training Acc: 1.0000, Validation Acc: 0.6578
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.0291 , Training Acc: 0.9750, Validation Acc: 0.6372
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.0182 , Training Acc: 1.0000, Validation Acc: 0.6434
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0308 , Training Acc: 1.0000, Validation Acc: 0.6424
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.0341 , Training Acc: 1.0000, Validation Acc: 0.6224
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0292 , Training Acc: 1.0000, Validation Acc: 0.6366
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.0109 , Training Acc: 1.0000, Validation Acc: 0.6428
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.0219 , Training Acc: 1.0000, Validation Acc: 0.6348
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0330 , Training Acc: 1.0000, Validation Acc: 0.6444
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.0126 , Training Acc: 1.0000, Validation Acc: 0.6324
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0119 , Training Acc: 1.0000, Validation Acc: 0.6350
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0109 , Training Acc: 1.0000, Validation Acc: 0.6422
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.0086 , Training Acc: 1.0000, Validation Acc: 0.6366
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0149 , Training Acc: 1.0000, Validation Acc: 0.6468
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.0086 , Training Acc: 1.0000, Validation Acc: 0.6334
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0099 , Training Acc: 1.0000, Validation Acc: 0.6410
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0117 , Training Acc: 1.0000, Validation Acc: 0.6334
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0043 , Training Acc: 1.0000, Validation Acc: 0.6368
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0044 , Training Acc: 1.0000, Validation Acc: 0.6554
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0081 , Training Acc: 1.0000, Validation Acc: 0.6232
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0089 , Training Acc: 1.0000, Validation Acc: 0.6304
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0084 , Training Acc: 1.0000, Validation Acc: 0.6326
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.6420
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0149 , Training Acc: 1.0000, Validation Acc: 0.6454
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0237 , Training Acc: 1.0000, Validation Acc: 0.6354
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0065 , Training Acc: 1.0000, Validation Acc: 0.6478
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0020 , Training Acc: 1.0000, Validation Acc: 0.6380
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6556
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0091 , Training Acc: 1.0000, Validation Acc: 0.6466
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0078 , Training Acc: 1.0000, Validation Acc: 0.6470
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0073 , Training Acc: 1.0000, Validation Acc: 0.6514
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0046 , Training Acc: 1.0000, Validation Acc: 0.6278
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0068 , Training Acc: 1.0000, Validation Acc: 0.6524
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0051 , Training Acc: 1.0000, Validation Acc: 0.6550
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0123 , Training Acc: 1.0000, Validation Acc: 0.6502
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0024 , Training Acc: 1.0000, Validation Acc: 0.6556
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0018 , Training Acc: 1.0000, Validation Acc: 0.6464
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.6516
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0026 , Training Acc: 1.0000, Validation Acc: 0.6562
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0028 , Training Acc: 1.0000, Validation Acc: 0.6392
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0013 , Training Acc: 1.0000, Validation Acc: 0.6572
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6526
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6710
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0034 , Training Acc: 1.0000, Validation Acc: 0.6420
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0087 , Training Acc: 1.0000, Validation Acc: 0.6534
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6496
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0061 , Training Acc: 1.0000, Validation Acc: 0.6424
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0129 , Training Acc: 1.0000, Validation Acc: 0.6444
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0116 , Training Acc: 1.0000, Validation Acc: 0.6460
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0164 , Training Acc: 1.0000, Validation Acc: 0.6424
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0012 , Training Acc: 1.0000, Validation Acc: 0.6562
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0022 , Training Acc: 1.0000, Validation Acc: 0.6366
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.6480
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0012 , Training Acc: 1.0000, Validation Acc: 0.6472
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0027 , Training Acc: 1.0000, Validation Acc: 0.6536
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6404
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6440
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6532
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0063 , Training Acc: 1.0000, Validation Acc: 0.6552
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0030 , Training Acc: 1.0000, Validation Acc: 0.6442
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0043 , Training Acc: 1.0000, Validation Acc: 0.6558
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0021 , Training Acc: 1.0000, Validation Acc: 0.6414
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0277 , Training Acc: 0.9750, Validation Acc: 0.6536
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0042 , Training Acc: 1.0000, Validation Acc: 0.6458
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0033 , Training Acc: 1.0000, Validation Acc: 0.6524
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6624
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0030 , Training Acc: 1.0000, Validation Acc: 0.6428
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0013 , Training Acc: 1.0000, Validation Acc: 0.6540
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0020 , Training Acc: 1.0000, Validation Acc: 0.6582
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0086 , Training Acc: 1.0000, Validation Acc: 0.6356
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0028 , Training Acc: 1.0000, Validation Acc: 0.6652
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0026 , Training Acc: 1.0000, Validation Acc: 0.6312
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0002 , Training Acc: 1.0000, Validation Acc: 0.6598
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0036 , Training Acc: 1.0000, Validation Acc: 0.6582
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6492
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6556
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0017 , Training Acc: 1.0000, Validation Acc: 0.6362
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0002 , Training Acc: 1.0000, Validation Acc: 0.6534
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6546
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0011 , Training Acc: 1.0000, Validation Acc: 0.6464
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6596
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0034 , Training Acc: 1.0000, Validation Acc: 0.6190
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0018 , Training Acc: 1.0000, Validation Acc: 0.6422
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0003 , Training Acc: 1.0000, Validation Acc: 0.6618
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6430
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6584
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6378
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0063 , Training Acc: 1.0000, Validation Acc: 0.6538
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0023 , Training Acc: 1.0000, Validation Acc: 0.6590
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0018 , Training Acc: 1.0000, Validation Acc: 0.6592
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0022 , Training Acc: 1.0000, Validation Acc: 0.6576
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0046 , Training Acc: 1.0000, Validation Acc: 0.6202
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6406
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6514
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0013 , Training Acc: 1.0000, Validation Acc: 0.6510
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6598
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6384
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6428
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0027 , Training Acc: 1.0000, Validation Acc: 0.6568
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6474
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6620
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6496
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0011 , Training Acc: 1.0000, Validation Acc: 0.6570
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6514
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6488
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0028 , Training Acc: 1.0000, Validation Acc: 0.6616
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6442
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0030 , Training Acc: 1.0000, Validation Acc: 0.6540
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0046 , Training Acc: 1.0000, Validation Acc: 0.6532
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0103 , Training Acc: 1.0000, Validation Acc: 0.6484
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0003 , Training Acc: 1.0000, Validation Acc: 0.6546
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6496
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6572
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6670
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6648
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0024 , Training Acc: 1.0000, Validation Acc: 0.6556
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6388
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0003 , Training Acc: 1.0000, Validation Acc: 0.6524
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.6596
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6566
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6534
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6458
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0003 , Training Acc: 1.0000, Validation Acc: 0.6454
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6520
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6618
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0017 , Training Acc: 1.0000, Validation Acc: 0.6544
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0032 , Training Acc: 1.0000, Validation Acc: 0.6380
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6624
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0018 , Training Acc: 1.0000, Validation Acc: 0.6430
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0052 , Training Acc: 1.0000, Validation Acc: 0.6622
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6644
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6338
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.6590
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6536
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0005 , Training Acc: 1.0000, Validation Acc: 0.6482
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0017 , Training Acc: 1.0000, Validation Acc: 0.6538
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0043 , Training Acc: 1.0000, Validation Acc: 0.6400
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0032 , Training Acc: 1.0000, Validation Acc: 0.6412
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0066 , Training Acc: 1.0000, Validation Acc: 0.6542
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6582
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6602
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.6420
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6492
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0059 , Training Acc: 1.0000, Validation Acc: 0.6506
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0017 , Training Acc: 1.0000, Validation Acc: 0.6510
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0093 , Training Acc: 1.0000, Validation Acc: 0.6632
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0002 , Training Acc: 1.0000, Validation Acc: 0.6420
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6512
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6512
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6578
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.6590
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0075 , Training Acc: 1.0000, Validation Acc: 0.6266
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0022 , Training Acc: 1.0000, Validation Acc: 0.6470
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6592
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6640
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0016 , Training Acc: 1.0000, Validation Acc: 0.6462
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0008 , Training Acc: 1.0000, Validation Acc: 0.6478
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6392
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0004 , Training Acc: 1.0000, Validation Acc: 0.6512
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0009 , Training Acc: 1.0000, Validation Acc: 0.6494
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0021 , Training Acc: 1.0000, Validation Acc: 0.6628
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0010 , Training Acc: 1.0000, Validation Acc: 0.6526
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0000 , Training Acc: 1.0000, Validation Acc: 0.6510
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6548
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0007 , Training Acc: 1.0000, Validation Acc: 0.6540
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0013 , Training Acc: 1.0000, Validation Acc: 0.6634
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0000 , Training Acc: 1.0000, Validation Acc: 0.6568
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0003 , Training Acc: 1.0000, Validation Acc: 0.6656
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0001 , Training Acc: 1.0000, Validation Acc: 0.6574
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0024 , Training Acc: 1.0000, Validation Acc: 0.6522
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0006 , Training Acc: 1.0000, Validation Acc: 0.6494
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0012 , Training Acc: 1.0000, Validation Acc: 0.6458
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0015 , Training Acc: 1.0000, Validation Acc: 0.6658

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6632713607594937

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
